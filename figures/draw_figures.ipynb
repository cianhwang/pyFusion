# %%
import pandas as pd

# %%
df = pd.read_csv('total_loss.csv')

# %%
df
# Out:
#         Wall time  Step  Total_loss
# 0    1.585272e+09     0    0.671293
# 1    1.585273e+09     1    0.471560
# 2    1.585273e+09     2    0.433761
# 3    1.585273e+09     3    0.377055
# 4    1.585274e+09     4    0.347679
# ..            ...   ...         ...
# 195  1.585347e+09   195    0.173718
# 196  1.585348e+09   196    0.167056
# 197  1.585348e+09   197    0.160423
# 198  1.585348e+09   198    0.172593
# 199  1.585349e+09   199    0.167617
#
# [200 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.plot(x = 'Step', y = 'Total_loss')

# %%
plot = df.plot(x = 'Step', y = 'Total_loss')
fig = plot.get_figure()
fig.savefig("total_loss.png")

# %%
from matplotlib.ticker import MaxNLocator
T = [2, 3, 4]
random = [2.856, 2.642, 2.604]

greedy = [1.440, 1.414, 1.323]
ours = [1.427, 1.398, 1.293]

# plt.plot(T, random)
fig, ax = plt.subplots()
ax.plot(T, greedy, label = 'greedy')
ax.plot(T, ours, label = 'ours')
ax.set_xlabel('T')
ax.set_ylabel('MSE x1000')
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
ax.legend()
plt.savefig('greedy_vs_ours.png')
